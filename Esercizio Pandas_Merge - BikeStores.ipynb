# %%
import numpy as np
import pymongo
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://BELLOTTA:xxxlllgg2Gcxxx@cluster0.of3sn.mongodb.net/test")
#pass xxxlllgg2Gcxxx
db = client.Bellotta # nome del database
categorie = db.categories
brand = db.brands
prodotti = db.products
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-2-7ff3fa922d76> in <module>()
#       1 import pymongo
# ----> 2 client = pymongo.MongoClient("mongodb+srv://BELLOTTA:xxxlllgg2Gcxxx@cluster0.of3sn.mongodb.net/test")
#       3 #pass xxxlllgg2Gcxxx
#       4 db = client.Bellotta # nome del database
#       5 categorie = db.categories
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     670                 res = uri_parser.parse_uri(
#     671                     entity, port, validate=True, warn=True, normalize=False,
# --> 672                     connect_timeout=timeout)
#     673                 seeds.update(res["nodelist"])
#     674                 username = res["username"] or username
#
# /usr/local/lib/python3.7/dist-packages/pymongo/uri_parser.py in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout)
#     451                 'installed to use mongodb+srv:// URIs. '
#     452                 'To fix this error install pymongo with the srv extra:\n '
# --> 453                 '%s -m pip install "pymongo[srv]"' % (python_path))
#     454         is_srv = True
#     455         scheme_free = uri[SRV_SCHEME_LEN:]
#
# ConfigurationError: The "dnspython" module must be installed to use mongodb+srv:// URIs. To fix this error install pymongo with the srv extra:
#  /usr/bin/python3 -m pip install "pymongo[srv]"

# %%
rest = db.BikeStores #nome della collection
rest

# %%
pip install xlrd

# %%
df_categorie = pd.DataFrame(multe.find())
df_brand = pd.DataFrame(multe1.find())
df_prodotti = pd.DataFrame(prop.find())

# %% [markdown]
# #1. il catalogo complessivo dei prodotti. Visualizzare il nome del prodotto, il nome della marca e la categoria

# %% [markdown]
# #2. il numero di prodotti per ogni categoria. Visualizzare i nomi delle categorie e il numero dei prodotti.

# %% [markdown]
# #3. il numero di prodotti per ogni marca (brand). Visualizzare i nomi dei brand e il numero di prodotti

# %% [markdown]
# #4. i nomi dei prodotti della marca Trek

# %% [markdown]
# #5. i prodotti delle categorie che hanno la parola 'Bikes' nel nome

# %% [markdown]
# #6. la categoria che ha il prodotto che costa di più

# %% [markdown]
# #7. i brand con almeno 100 prodotti. Viaulizzare il nome del brand e il numero di prodotti

# %% [markdown]
# #8. la marca del prodotto 'Electra Townie Original 21D - 2016'

# %% [markdown]
# #9. il numero di prodotti per ogni anno. Visualizzare l'anno e il numero di prodotti
