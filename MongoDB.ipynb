# %%
import pymongo

# %%
# stringa di connessione 3.4 recuperata da Atlas https://www.mongodb.com/cloud/atlas/register
client = pymongo.MongoClient("mongodb://BELLOTTA:Pietoto2003!@cluster0-shard-00-00.of3sn.mongodb.net:27017,cluster0-shard-00-01.of3sn.mongodb.net:27017,cluster0-shard-00-02.of3sn.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-axo3gt-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Bellotta # nome del database

# %%
rest = db.Prime #nome della collection
rest
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.of3sn.mongodb.net:27017', 'cluster0-shard-00-00.of3sn.mongodb.net:27017', 'cluster0-shard-00-01.of3sn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-axo3gt-shard-0', authsource='admin', retrywrites=True, w='majority'), 'Bellotta'), 'Prime')

# %%
import pandas as pd
df = pd.DataFrame.from_records(db.Prime.find())
df
# Out:
#                           _id    0  ...   10   11
# 0    6193d5cd78f3832f9e911036    3  ...  NaN  NaN
# 1    6193d5cd78f3832f9e911039    6  ...  NaN  NaN
# 2    6193d5cd78f3832f9e91103d   10  ...  NaN  NaN
# 3    6193d5cd78f3832f9e911059   38  ...  NaN  NaN
# 4    6193d5cd78f3832f9e91105a   39  ...  NaN  NaN
# ..                        ...  ...  ...  ...  ...
# 399  6193d5cd78f3832f9e911180  333  ...  NaN  NaN
# 400  6193d5cd78f3832f9e911184  337  ...  NaN  NaN
# 401  6193d5cd78f3832f9e911198  357  ...  NaN  NaN
# 402  6193d5cd78f3832f9e9111a1  366  ...  NaN  NaN
# 403  6193d5cd78f3832f9e9111af  380  ...  NaN  NaN
#
# [404 rows x 21 columns]

# %%
df.dropna(subset=['8','9'], inplace=True)
df
# Out:
#                           _id    0  ...   10   11
# 2    6193d5cd78f3832f9e91103d   10  ...  NaN  NaN
# 9    6193d5cd78f3832f9e911085   82  ...  NaN  NaN
# 25   6193d5cd78f3832f9e9110d9  166  ...  NaN  NaN
# 29   6193d5cd78f3832f9e911112  223  ...  NaN  NaN
# 44   6193d5cd78f3832f9e911176  323  ...  NaN  NaN
# 58   6193d5cd78f3832f9e911042   15  ...  NaN  NaN
# 63   6193d5cd78f3832f9e911072   63  ...  NaN  NaN
# 115  6193d5cd78f3832f9e911078   69  ...  NaN  NaN
# 151  6193d5cd78f3832f9e911195  354  ...  NaN  NaN
# 206  6193d5cd78f3832f9e911190  349  ...  NaN  NaN
# 225  6193d5cd78f3832f9e91104e   27  ...  16+  NaN
# 227  6193d5cd78f3832f9e911058   37  ...  16+  NaN
# 257  6193d5cd78f3832f9e91105b   40  ...  NaN  NaN
# 273  6193d5cd78f3832f9e9110c5  146  ...    8  18+
# 300  6193d5cd78f3832f9e91116e  315  ...  NaN  NaN
# 314  6193d5cd78f3832f9e91106f   60  ...  NaN  NaN
# 344  6193d5cd78f3832f9e911113  224  ...  NaN  NaN
# 367  6193d5cd78f3832f9e911046   19  ...  NaN  NaN
# ...

# %%
df['9'] = df['9'].str.replace(r'+', '')
df
# Out:
#                           _id    0  ...   10   11
# 2    6193d5cd78f3832f9e91103d   10  ...  NaN  NaN
# 9    6193d5cd78f3832f9e911085   82  ...  NaN  NaN
# 25   6193d5cd78f3832f9e9110d9  166  ...  NaN  NaN
# 29   6193d5cd78f3832f9e911112  223  ...  NaN  NaN
# 44   6193d5cd78f3832f9e911176  323  ...  NaN  NaN
# 58   6193d5cd78f3832f9e911042   15  ...  NaN  NaN
# 63   6193d5cd78f3832f9e911072   63  ...  NaN  NaN
# 115  6193d5cd78f3832f9e911078   69  ...  NaN  NaN
# 151  6193d5cd78f3832f9e911195  354  ...  NaN  NaN
# 206  6193d5cd78f3832f9e911190  349  ...  NaN  NaN
# 225  6193d5cd78f3832f9e91104e   27  ...  16+  NaN
# 227  6193d5cd78f3832f9e911058   37  ...  16+  NaN
# 257  6193d5cd78f3832f9e91105b   40  ...  NaN  NaN
# 273  6193d5cd78f3832f9e9110c5  146  ...    8  18+
# 300  6193d5cd78f3832f9e91116e  315  ...  NaN  NaN
# 314  6193d5cd78f3832f9e91106f   60  ...  NaN  NaN
# 344  6193d5cd78f3832f9e911113  224  ...  NaN  NaN
# 367  6193d5cd78f3832f9e911046   19  ...  NaN  NaN
# ...
